# %%
import pymongo

# Replace the uri string with your MongoDB deployment's connection string.
conn_str = "mongodb+srv://suvratkumra2018:CPSC571Password@cpsc571-custer.q7ctnor.mongodb.net/?retryWrites=true&w=majority"

# set a 5-second connection timeout
client = pymongo.MongoClient(conn_str, serverSelectionTimeoutMS=5000)

try:
    print(client.server_info())
except Exception:
    print("Unable to connect to the server.")
# Out:
# {'version': '5.0.14', 'gitVersion': '1b3b0073a0b436a8a502b612f24fb2bd572772e5', 'modules': ['enterprise'], 'allocator': 'tcmalloc', 'javascriptEngine': 'mozjs', 'sysInfo': 'deprecated', 'versionArray': [5, 0, 14, 0], 'bits': 64, 'debug': False, 'maxBsonObjectSize': 16777216, 'storageEngines': ['devnull', 'ephemeralForTest', 'inMemory', 'queryable_wt', 'wiredTiger'], 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1677220009, 5), 'signature': {'hash': b'\x16\x86@\x8f`\xa7\x18\xcdS\xc9YZ\x8elk}\xc9x\xbc\x91', 'keyId': 7146223138366291973}}, 'operationTime': Timestamp(1677220009, 5)}

# %%
client
# Out:
# MongoClient(host=['ac-ur940lj-shard-00-00.q7ctnor.mongodb.net:27017', 'ac-ur940lj-shard-00-02.q7ctnor.mongodb.net:27017', 'ac-ur940lj-shard-00-01.q7ctnor.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-8z33g9-shard-0', tls=True, serverselectiontimeoutms=5000)

# %%
# Adding the api_key, unique for everyone
api_key = "RGAPI-71b17a2b-88fa-4939-b429-7ed54c36578e"

# %%
api_url = "https://na1.api.riotgames.com/lol/summoner/v4/summoners/by-name/CatchThatVoltage"

# %%
api_key
# Out:
# 'RGAPI-71b17a2b-88fa-4939-b429-7ed54c36578e'

# %%
api_url
# Out:
# 'https://na1.api.riotgames.com/lol/summoner/v4/summoners/by-name/CatchThatVoltage'

# %%
import requests

# %%
requests.get(api_url)
# Out:
# <Response [401]>

# %%
api_url = api_url + "?api_key=" + api_key

# %%
api_url
# Out:
# 'https://na1.api.riotgames.com/lol/summoner/v4/summoners/by-name/MindYourGamesYT?api_key=RGAPI-71b17a2b-88fa-4939-b429-7ed54c36578e'

# %%
response = requests.get(api_url) # to get the response we want from the API

# %%
playerInfo = response.json()  # to get the response in json format.

# %%
puuid = playerInfo['puuid']

# %%
puuid
# Out:
# '8IkjL3JbHusykg8_eizgIGOhlqQVKZVnWoUQmLb4HDslFaz-B0OPPGAuVkc3iRUt-YbaBcFTabnYfQ'

# %%
playerInfo
# Out:
# {'id': 'dftu2fPk-QFgQgiSqX1PdWfe-IHjUVwEzIPI8i5Pc1ZYFJW2L7-haTEnFg',
#  'accountId': 'LPfSF8LrAc1XRG8X01_6Ogt9vaqMoX8aQuLNxp-Ef2KKJJWNhLd0Bb_I',
#  'puuid': '8IkjL3JbHusykg8_eizgIGOhlqQVKZVnWoUQmLb4HDslFaz-B0OPPGAuVkc3iRUt-YbaBcFTabnYfQ',
#  'name': 'CatchThatVoltage',
#  'profileIconId': 29,
#  'revisionDate': 1677185846000,
#  'summonerLevel': 1}

# %%
accountId = playerInfo['accountId']

# %%
accountId
# Out:
# 'LPfSF8LrAc1XRG8X01_6Ogt9vaqMoX8aQuLNxp-Ef2KKJJWNhLd0Bb_I'

# %%
puuid = playerInfo['puuid']

# %%
puuid
# Out:
# '8IkjL3JbHusykg8_eizgIGOhlqQVKZVnWoUQmLb4HDslFaz-B0OPPGAuVkc3iRUt-YbaBcFTabnYfQ'

# %%
#######################################

# %%
getGamesURL = 'https://europe.api.riotgames.com/lol/match/v5/matches/by-puuid/DexOCDO001rqCT4u392-vxNQt4evAJE7bE4Va7x5NcQZ4zDcW0EgBhuQghd45FiYfC03oF-CvCA68Q/ids?start=0&count=20'

# %%
getGamesURL
# Out:
# 'https://europe.api.riotgames.com/lol/match/v5/matches/by-puuid/DexOCDO001rqCT4u392-vxNQt4evAJE7bE4Va7x5NcQZ4zDcW0EgBhuQghd45FiYfC03oF-CvCA68Q/ids?start=0&count=20'

# %%
requests.get(api_url)
# Out:
# <Response [404]>

# %%
response = requests.get(api_url)

# %%
response
# Out:
# <Response [401]>

# %%
getUserSummonerID = "https://europe.api.riotgames.com/riot/account/v1/accounts/by-puuid/5m-cr1Zt3WGIMuam1W1RF03ONWyGxGdUWZFHV6zvq9jT968omM9wl9V83HPi7ch1rM9pPwNZ2qWO7Q"

# %%
getUserSummonerID = getUserSummonerID + "?api_key=" + api_key

# %%
accountInformation = requests.get(getUserSummonerID)

# %%
response_accountInformation = accountInformation.json()

# %%
AccountPuuid = response_accountInformation['puuid']

# %%
AccountPuuid = 'DexOCDO001rqCT4u392-vxNQt4evAJE7bE4Va7x5NcQZ4zDcW0EgBhuQghd45FiYfC03oF-CvCA68Q'

# %%
GetMatchDataURL = 'https://europe.api.riotgames.com/lol/match/v5/matches/by-puuid/DexOCDO001rqCT4u392-vxNQt4evAJE7bE4Va7x5NcQZ4zDcW0EgBhuQghd45FiYfC03oF-CvCA68Q/ids?start=0&count=50' + "&api_key=" + api_key

# %%
GetMatchDataURL
# Out:
# 'https://europe.api.riotgames.com/lol/match/v5/matches/by-puuid/DexOCDO001rqCT4u392-vxNQt4evAJE7bE4Va7x5NcQZ4zDcW0EgBhuQghd45FiYfC03oF-CvCA68Q/ids?start=0&count=50&api_key=RGAPI-71b17a2b-88fa-4939-b429-7ed54c36578e'

# %%
GetMatchData = requests.get(GetMatchDataURL)

# %%
Response_GetMatchData = GetMatchData.json()

# %%
Response_GetMatchData
# Out:
# ['EUW1_6191873513',
#  'EUW1_6191855096',
#  'EUW1_6191804736',
#  'EUW1_6179976552',
#  'EUW1_6179953300',
#  'EUW1_6179938134',
#  'EUW1_6177504395',
#  'EUW1_6177476428',
#  'EUW1_6176483969',
#  'EUW1_6176460940',
#  'EUW1_6169917247',
#  'EUW1_6168611260',
#  'EUW1_5599945958',
#  'EUW1_5600011474',
#  'EUW1_5599876429',
#  'EUW1_5599458445',
#  'EUW1_5551686741',
#  'EUW1_5551619759',
#  'EUW1_5551221929',
#  'EUW1_5549406884',
#  'EUW1_5549357323',
#  'EUW1_5546714567',
#  'EUW1_5289631903',
#  'EUW1_5289566269',
#  'EUW1_5289348112',
#  'EUW1_5280503836',
#  'EUW1_5280407225',
#  'EUW1_5279485491',
#  'EUW1_5279369121',
#  'EUW1_5279120584',
#  'EUW1_5279073553',
#  'EUW1_5278881121',
#  'EUW1_5278818165',
#  'EUW1_5278705294',
#  'EUW1_5277512891',
#  'EUW1_5276875035',
#  'EUW1_5276781009',
#  'EUW1_5276777376',
#  'EUW1_5273100218',
#  'EUW1_5267594814',
#  'EUW1_5267349192',
#  'EUW1_5264114748',
#  'EUW1_5264014916',
#  'EUW1_5263940058',
#  'EUW1_5261150490',
#  'EUW1_5261013953',
#  'EUW1_5253726173',
#  'EUW1_5253653891',
#  'EUW1_5252697347',
#  'EUW1_5252691024']

# %%
list = Response_GetMatchData

# %%
list
# Out:
# ['EUW1_6191873513',
#  'EUW1_6191855096',
#  'EUW1_6191804736',
#  'EUW1_6179976552',
#  'EUW1_6179953300',
#  'EUW1_6179938134',
#  'EUW1_6177504395',
#  'EUW1_6177476428',
#  'EUW1_6176483969',
#  'EUW1_6176460940',
#  'EUW1_6169917247',
#  'EUW1_6168611260',
#  'EUW1_5599945958',
#  'EUW1_5600011474',
#  'EUW1_5599876429',
#  'EUW1_5599458445',
#  'EUW1_5551686741',
#  'EUW1_5551619759',
#  'EUW1_5551221929',
#  'EUW1_5549406884',
#  'EUW1_5549357323',
#  'EUW1_5546714567',
#  'EUW1_5289631903',
#  'EUW1_5289566269',
#  'EUW1_5289348112',
#  'EUW1_5280503836',
#  'EUW1_5280407225',
#  'EUW1_5279485491',
#  'EUW1_5279369121',
#  'EUW1_5279120584',
#  'EUW1_5279073553',
#  'EUW1_5278881121',
#  'EUW1_5278818165',
#  'EUW1_5278705294',
#  'EUW1_5277512891',
#  'EUW1_5276875035',
#  'EUW1_5276781009',
#  'EUW1_5276777376',
#  'EUW1_5273100218',
#  'EUW1_5267594814',
#  'EUW1_5267349192',
#  'EUW1_5264114748',
#  'EUW1_5264014916',
#  'EUW1_5263940058',
#  'EUW1_5261150490',
#  'EUW1_5261013953',
#  'EUW1_5253726173',
#  'EUW1_5253653891',
#  'EUW1_5252697347',
#  'EUW1_5252691024']

# %%
aggregated_result = []

# %%
for i in range(0,50):
    url = "https://europe.api.riotgames.com/lol/match/v5/matches/" + list[i] + "?api_key=" + api_key
    result = requests.get(url).json()
    aggregated_result.append(result)

# %%
aggregated_result
# Out:
# [{'metadata': {'dataVersion': '2',
#    'matchId': 'EUW1_6191873513',
#    'participants': ['k86L-t5aoM8nYprP8tJqyOAB_8g9_WFFZ3ISPeW48cJvw26nKR1rsScuNa628iACZdxWIYCCiAAqeQ',
#     '83KP2e3aQq2wUYj_cbzEv7yKJ1EzJR549Nv3zkcBjv5-0wJGGse2Me9Quzc03c6JruB-zJvRh0aX6A',
#     'DexOCDO001rqCT4u392-vxNQt4evAJE7bE4Va7x5NcQZ4zDcW0EgBhuQghd45FiYfC03oF-CvCA68Q',
#     'ZRHt3hu1ECYzkMsZlWFHI376PAnBtso5_OrHVxe4hPr4YD6lHLrGBUKWM5KqHRXoZrRtZttCBBuBSA',
#     'mOkgOSPnkqSYHgqS1arfKJ1yzOApIdKM9F7Cx-AEA3lvwCMt1c6VTuINXBd8zM2tjdVRVqtNs2qo3g',
#     '3NUJVhSEfyr_35G61JWDDZ5roL9Iv_7P-XWKSuB1VWNijnnYc9dMC-GAWah7M1murowV7CJ148dSXA',
#     'Yc2QkZSsC_7i7uM2ZK3P3TiFI2BVxRnTZlBYkRmME0vPWq8nTnYYShKYLfprtmmcJy1n3hAiQUt6aQ',
#     'DfyKFw_XSy5ZRt4_XFiPGcu-yTXl-lAPBUM7TChPATNiORN5y1Wt0bzRIObhOgwwpb60veLnJQ5Xgw',
#     'XO6sCLl0ALeLTHGEyuuNuaveZ7Ixc63GxAcM4jaO5N7fo8E-sfG5CeFG0kyFqvbeqMrLZPUAG75pEA',
#     '-0SGC_-2vNwEoMsUWaAZWn9xdB_JQskZP8Kh76NTlXjIWB2YUdqPMWf32-vac3GyO9hsUBkl4jW8MA']},
#   'info': {'gameCreation': 1671212318023,
#    'gameDuration': 2809,
#    'gameEndTimestamp': 1671215371630,
#    'gameId': 6191873513,
#    'gameMode': 'CLASSIC',
#    'gameName': 'teambuilder-match-6191873513',
#    'gameStartTimestamp': 1671212562434,
#    'gameType': 'MATCHED_GAME',
#    'gameVersion': '12.23.483.5208',
#    'mapId': 11,
#    'participants': [{'allInPings': 1,
#      'assistMePings': 9,
#      'assists': 11,
#      'baitPings': 0,
#      'baronKills': 0,
#      'basicPings': 0,
#      'bountyLevel': 1,
#      'challenges': {'12AssistStreakCount': 0,
#       'abilityUses': 274,
#       'acesBefore15Minutes': 0,
#       'alliedJungleMonsterKills': 13.200000017881393,
#       'baronBuffGoldAdvantageOverThreshold': 1,
#       'baronTakedowns': 0,
#       'blastConeOppositeOpponentCount': 0,
#       'bountyGold': 0,
#       'buffsStolen': 0,
#       'completeSupportQuestInTime': 0,
#       'controlWardTimeCoverageInRiverOrEnemyHalf': 0.040043398521628984,
#       'controlWardsPlaced': 1,
#       'damagePerMinute': 406.96831526256864,
#       'damageTakenOnTeamPercentage': 0.2044724335107806,
#       'dancedWithRiftHerald': 0,
#       'deathsByEnemyChamps': 11,
#       'dodgeSkillShotsSmallWindow': 13,
#       'doubleAces': 0,
#       'dragonTakedowns': 1,
#       'earliestBaron': 2048.992109979023,
#       'earliestDragonTakedown': 2368.012880635064,
#       'earliestElderDragon': 2748.92878605061,
#       'earlyLaningPhaseGoldExpAdvantage': 0,
#       'effectiveHealAndShielding': 0,
#       'elderDragonKillsWithOpposingSoul': 0,
#       'elderDragonMultikills': 0,
#       'enemyChampionImmobilizations': 0,
#       'enemyJungleMonsterKills': 0,
#       'epicMonsterKillsNearEnemyJungler': 0,
#       'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#       'epicMonsterSteals': 0,
#       'epicMonsterStolenWithoutSmite': 0,
#       'flawlessAces': 0,
#       'fullTeamTakedown': 0,
#       'gameLength': 2809.272754470758,
#       'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#       'goldPerMinute': 329.2385188690931,
#       'hadOpenNexus': 0,
#       'immobilizeAndKillWithAlly': 0,
#       'initialBuffCount': 0,
#       'initialCrabCount': 0,
#       'jungleCsBefore10Minutes': 0,
#       'junglerTakedownsNearDamagedEpicMonster': 0,
#       'kTurretsDestroyedBeforePlatesFall': 0,
#       'kda': 1.1818181818181819,
#       'killAfterHiddenWithAlly': 1,
#       'killParticipation': 0.24074074074074073,
#       'killedChampTookFullTeamDamageSurvived': 0,
#       'killsNearEnemyTurret': 0,
#       'killsOnOtherLanesEarlyJungleAsLaner': 0,
#       'killsOnRecentlyHealedByAramPack': 0,
#       'killsUnderOwnTurret': 1,
#       'killsWithHelpFromEpicMonster': 0,
#       'knockEnemyIntoTeamAndKill': 0,
#       'landSkillShotsEarlyGame': 0,
#       'laneMinionsFirst10Minutes': 35,
#       'laningPhaseGoldExpAdvantage': 0,
#       'legendaryCount': 0,
#       'lostAnInhibitor': 1,
#       'maxCsAdvantageOnLaneOpponent': 5,
#       'maxKillDeficit': 8,
#       'maxLevelLeadLaneOpponent': 1,
#       'moreEnemyJungleThanOpponent': 0,
#       'multiKillOneSpell': 0,
#       'multiTurretRiftHeraldCount': 0,
#       'multikills': 0,
#       'multikillsAfterAggressiveFlash': 0,
#       'mythicItemUsed': 4633,
#       'outerTurretExecutesBefore10Minutes': 0,
#       'outnumberedKills': 1,
#       'outnumberedNexusKill': 0,
#       'perfectDragonSoulsTaken': 0,
#       'perfectGame': 0,
#       'pickKillWithAlly': 11,
#       'playedChampSelectPosition': 1,
#       'poroExplosions': 0,
#       'quickCleanse': 0,
#       'quickFirstTurret': 0,
#       'quickSoloKills': 0,
#       'riftHeraldTakedowns': 1,
#       'saveAllyFromDeath': 0,
#       'scuttleCrabKills': 0,
#       'skillshotsDodged': 70,
#       'skillshotsHit': 42,
#       'snowballsHit': 0,
#       'soloBaronKills': 0,
#       'soloKills': 1,
#       'stealthWardsPlaced': 8,
#       'survivedSingleDigitHpCount': 0,
#       'survivedThreeImmobilizesInFight': 0,
#       'takedownOnFirstTurret': 0,
#       'takedowns': 13,
#       'takedownsAfterGainingLevelAdvantage': 0,
#       'takedownsBeforeJungleMinionSpawn': 0,
#       'takedownsFirstXMinutes': 2,
#       'takedownsInAlcove': 1,
#       'takedownsInEnemyFountain': 0,
#       'teamBaronKills': 2,
#       'teamDamagePercentage': 0.09563459314211248,
#       'teamElderDragonKills': 1,
#       'teamRiftHeraldKills': 2,
#       'threeWardsOneSweeperCount': 0,
#       'tookLargeDamageSurvived': 0,
#       'turretPlatesTaken': 0,
#       'turretTakedowns': 3,
#       'turretsTakenWithRiftHerald': 5,
#       'twentyMinionsIn3SecondsCount': 9,
#       'unseenRecalls': 0,
#       'visionScoreAdvantageLaneOpponent': -0.40513014793395996,
#       'visionScorePerMinute': 0.3194233508703912,
#       'wardTakedowns': 0,
#       'wardTakedownsBefore20M': 0,
#       'wardsGuarded': 0},
#      'champExperience': 24070,
#      'champLevel': 18,
#      'championId': 887,
#      'championName': 'Gwen',
#      'championTransform': 0,
#      'commandPings': 0,
#      'consumablesPurchased': 3,
#      'damageDealtToBuildings': 2234,
#      'damageDealtToObjectives': 8473,
#      'damageDealtToTurrets': 2234,
#      'damageSelfMitigated': 48084,
#      'dangerPings': 0,
#      'deaths': 11,
#      'detectorWardsPlaced': 1,
#      'doubleKills': 0,
#      'dragonKills': 0,
#      'eligibleForProgression': True,
#      'enemyMissingPings': 0,
#      'enemyVisionPings': 0,
#      'firstBloodAssist': False,
#      'firstBloodKill': False,
#      'firstTowerAssist': False,
#      'firstTowerKill': False,
#      'gameEndedInEarlySurrender': False,
#      'gameEndedInSurrender': False,
#      'getBackPings': 0,
#      'goldEarned': 15415,
#      'goldSpent': 14275,
#      'holdPings': 0,
#      'individualPosition': 'TOP',
#      'inhibitorKills': 0,
#      'inhibitorTakedowns': 1,
#      'inhibitorsLost': 5,
#      'item0': 4633,
#      'item1': 3157,
#      'item2': 3047,
#      'item3': 3115,
#      'item4': 3165,
#      'item5': 3108,
#      'item6': 3340,
#      'itemsPurchased': 26,
#      'killingSprees': 0,
#      'kills': 2,
#      'lane': 'TOP',
#      'largestCriticalStrike': 0,
#      'largestKillingSpree': 0,
#      'largestMultiKill': 1,
#      'longestTimeSpentLiving': 531,
#      'magicDamageDealt': 128224,
#      'magicDamageDealtToChampions': 10410,
#      'magicDamageTaken': 10482,
#      'needVisionPings': 0,
#      'neutralMinionsKilled': 13,
#      'nexusKills': 1,
#      'nexusLost': 0,
#      'nexusTakedowns': 1,
#      'objectivesStolen': 0,
#      'objectivesStolenAssists': 0,
#      'onMyWayPings': 1,
#      'participantId': 1,
#      'pentaKills': 0,
#      'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#       'styles': [{'description': 'primaryStyle',
#         'selections': [{'perk': 8010, 'var1': 708, 'var2': 0, 'var3': 0},
#          {'perk': 8009, 'var1': 1272, 'var2': 0, 'var3': 0},
#          {'perk': 9104, 'var1': 29, 'var2': 30, 'var3': 0},
#          {'perk': 8299, 'var1': 590, 'var2': 0, 'var3': 0}],
#         'style': 8000},
#        {'description': 'subStyle',
#         'selections': [{'perk': 8473, 'var1': 1859, 'var2': 0, 'var3': 0},
#          {'perk': 8242, 'var1': 147, 'var2': 0, 'var3': 0}],
#         'style': 8400}]},
#      'physicalDamageDealt': 49365,
#      'physicalDamageDealtToChampions': 1743,
#      'physicalDamageTaken': 31822,
#      'profileIcon': 683,
#      'pushPings': 0,
#      'puuid': 'k86L-t5aoM8nYprP8tJqyOAB_8g9_WFFZ3ISPeW48cJvw26nKR1rsScuNa628iACZdxWIYCCiAAqeQ',
#      'quadraKills': 0,
#      'riotIdName': '',
#      'riotIdTagline': '',
#      'role': 'SOLO',
#      'sightWardsBoughtInGame': 0,
#      'spell1Casts': 106,
#      'spell2Casts': 13,
#      'spell3Casts': 134,
#      'spell4Casts': 21,
#      'summoner1Casts': 5,
#      'summoner1Id': 6,
#      'summoner2Casts': 2,
#      'summoner2Id': 14,
#      'summonerId': '_yFpkmZLVO1BLPvp0q18BA1kR3HlN0MldP_WjDUDB_XfKAY',
#      'summonerLevel': 216,
#      'summonerName': 'Toni dos Bosques',
#      'teamEarlySurrendered': False,
#      'teamId': 100,
#      'teamPosition': 'TOP',
#      'timeCCingOthers': 4,
#      'timePlayed': 2809,
#      'totalDamageDealt': 256363,
#      'totalDamageDealtToChampions': 19054,
#      'totalDamageShieldedOnTeammates': 0,
#      'totalDamageTaken': 49188,
#      'totalHeal': 14449,
#      'totalHealsOnTeammates': 0,
#      'totalMinionsKilled': 205,
#      'totalTimeCCDealt': 36,
#      'totalTimeSpentDead': 406,
#      'totalUnitsHealed': 1,
#      'tripleKills': 0,
#      'trueDamageDealt': 78774,
#      'trueDamageDealtToChampions': 6900,
#      'trueDamageTaken': 6883,
#      'turretKills': 2,
#      'turretTakedowns': 3,
#      'turretsLost': 10,
#      'unrealKills': 0,
#      'visionClearedPings': 1,
#      'visionScore': 14,
#      'visionWardsBoughtInGame': 1,
#      'wardsKilled': 0,
#      'wardsPlaced': 9,
#      'win': True},
#     {'allInPings': 1,
#      'assistMePings': 12,
#      'assists': 8,
#      'baitPings': 0,
#      'baronKills': 2,
#      'basicPings': 0,
#      'bountyLevel': 0,
#      'challenges': {'12AssistStreakCount': 0,
#       'abilityUses': 733,
#       'acesBefore15Minutes': 0,
#       'alliedJungleMonsterKills': 122.90000015497208,
#       'baronBuffGoldAdvantageOverThreshold': 1,
#       'baronTakedowns': 2,
#       'blastConeOppositeOpponentCount': 0,
#       'bountyGold': 1575,
#       'buffsStolen': 1,
#       'completeSupportQuestInTime': 0,
#       'controlWardTimeCoverageInRiverOrEnemyHalf': 0.0519906320616153,
#       'controlWardsPlaced': 3,
#       'damagePerMinute': 1648.9983346678343,
#       'damageTakenOnTeamPercentage': 0.27593296209708507,
#       'dancedWithRiftHerald': 0,
#       'deathsByEnemyChamps': 6,
#       'dodgeSkillShotsSmallWindow': 57,
#       'doubleAces': 0,
#       'dragonTakedowns': 3,
#       'earliestBaron': 2048.992109979023,
#       'earliestDragonTakedown': 367.22768422277113,
#       'earliestElderDragon': 2748.92878605061,
#       'earlyLaningPhaseGoldExpAdvantage': 0,
#       'effectiveHealAndShielding': 0,
#       'elderDragonKillsWithOpposingSoul': 0,
#       'elderDragonMultikills': 1,
#       'enemyChampionImmobilizations': 48,
#       'enemyJungleMonsterKills': 18,
#       'epicMonsterKillsNearEnemyJungler': 0,
#       'epicMonsterKillsWithin30SecondsOfSpawn': 1,
#       'epicMonsterSteals': 0,
#       'epicMonsterStolenWithoutSmite': 0,
#       'fastestLegendary': 2065.4483923060607,
#       'flawlessAces': 0,
#       'fullTeamTakedown': 0,
#       'gameLength': 2809.272754470758,
#       'goldPerMinute': 596.3852061965881,
#       'hadOpenNexus': 0,
#       'highestChampionDamage': 1,
#       'immobilizeAndKillWithAlly': 26,
#       'initialBuffCount': 2,
#       'initialCrabCount': 1,
#       'jungleCsBefore10Minutes': 52.000000059604645,
#       'junglerKillsEarlyJungle': 0,
#       'junglerTakedownsNearDamagedEpicMonster': 1,
#       'kTurretsDestroyedBeforePlatesFall': 0,
#       'kda': 6.166666666666667,
#       'killAfterHiddenWithAlly': 8,
#       'killParticipation': 0.6851851851851852,
#       'killedChampTookFullTeamDamageSurvived': 0,
#       'killingSprees': 3,
#       'killsNearEnemyTurret': 3,
#       'killsOnLanersEarlyJungleAsJungler': 3,
#       'killsOnRecentlyHealedByAramPack': 0,
#       'killsUnderOwnTurret': 1,
#       'killsWithHelpFromEpicMonster': 1,
#       'knockEnemyIntoTeamAndKill': 0,
#       'landSkillShotsEarlyGame': 0,
#       'laneMinionsFirst10Minutes': 16,
#       'laningPhaseGoldExpAdvantage': 0,
#       'legendaryCount': 1,
#       'lostAnInhibitor': 1,
#       'maxCsAdvantageOnLaneOpponent': 78.79999974370003,
#       'maxKillDeficit': 8,
#       'maxLevelLeadLaneOpponent': 2,
#       'moreEnemyJungleThanOpponent': -42.500000059604645,
#       'multiKillOneSpell': 0,
#       'multiTurretRiftHeraldCount': 0,
#       'multikills': 5,
#       'multikillsAfterAggressiveFlash': 0,
#       'mythicItemUsed': 6693,
#       'outerTurretExecutesBefore10Minutes': 0,
#       'outnumberedKills': 8,
#       'outnumberedNexusKill': 0,
#       'perfectDragonSoulsTaken': 0,
#       'perfectGame': 0,
#       'pickKillWithAlly': 32,
#       'playedChampSelectPosition': 1,
#       'poroExplosions': 0,
#       'quickCleanse': 0,
#       'quickFirstTurret': 0,
#       'quickSoloKills': 4,
#       'riftHeraldTakedowns': 2,
#       'saveAllyFromDeath': 0,
#       'scuttleCrabKills': 3,
#       'shortestTimeToAceFromFirstTakedown': 48.08784818922982,
#       'skillshotsDodged': 288,
#       'skillshotsHit': 0,
#       'snowballsHit': 0,
#       'soloBaronKills': 0,
#       'soloKills': 4,
#       'stealthWardsPlaced': 0,
#       'survivedSingleDigitHpCount': 0,
#       'survivedThreeImmobilizesInFight': 0,
#       'takedownOnFirstTurret': 0,
#       'takedowns': 37,
#       'takedownsAfterGainingLevelAdvantage': 1,
#       'takedownsBeforeJungleMinionSpawn': 0,
#       'takedownsFirstXMinutes': 9,
#       'takedownsInAlcove': 0,
#       'takedownsInEnemyFountain': 1,
#       'teamBaronKills': 2,
#       'teamDamagePercentage': 0.38750261117068374,
#       'teamElderDragonKills': 1,
#       'teamRiftHeraldKills': 2,
#       'threeWardsOneSweeperCount': 0,
#       'tookLargeDamageSurvived': 0,
#       'turretPlatesTaken': 1,
#       'turretTakedowns': 3,
#       'turretsTakenWithRiftHerald': 5,
#       'twentyMinionsIn3SecondsCount': 6,
#       'unseenRecalls': 0,
#       'visionScoreAdvantageLaneOpponent': -0.6199592351913452,
#       'visionScorePerMinute': 0.5189621494714823,
#       'wardTakedowns': 3,
#       'wardTakedownsBefore20M': 3,
#       'wardsGuarded': 1},
#      'champExperience': 32407,
#      'champLevel': 18,
#      'championId': 77,
#      'championName': 'Udyr',
#      'championTransform': 0,
#      'commandPings': 18,
#      'consumablesPurchased': 9,
#      'damageDealtToBuildings': 2936,
#      'damageDealtToObjectives': 74293,
#      'damageDealtToTurrets': 2936,
#      'damageSelfMitigated': 111934,
#      'dangerPings': 0,
#      'deaths': 6,
#      'detectorWardsPlaced': 3,
#      'doubleKills': 4,
#      'dragonKills': 3,
#      'eligibleForProgression': True,
#      'enemyMissingPings': 32,
#      'enemyVisionPings': 0,
#      'firstBloodAssist': False,
#      'firstBloodKill': False,
#      'firstTowerAssist': False,
#      'firstTowerKill': False,
#      'gameEndedInEarlySurrender': False,
#      'gameEndedInSurrender': False,
#      'getBackPings': 0,
#      'goldEarned': 27923,
#      'goldSpent': 22675,
#      'holdPings': 4,
#      'individualPosition': 'JUNGLE',
#      'inhibitorKills': 0,
#      'inhibitorTakedowns': 0,
#      'inhibitorsLost': 5,
#      'item0': 3814,
#      'item1': 6693,
#      'item2': 3742,
#      'item3': 6333,
#      'item4': 6676,
#      'item5': 3075,
#      'item6': 3364,
#      'itemsPurchased': 34,
#      'killingSprees': 5,
#      'kills': 29,
#      'lane': 'JUNGLE',
#      'largestCriticalStrike': 922,
#      'largestKillingSpree': 15,
#      'largestMultiKill': 3,
#      'longestTimeSpentLiving': 914,
#      'magicDamageDealt': 92283,
#      'magicDamageDealtToChampions': 10826,
#      'magicDamageTaken': 25308,
#      'needVisionPings': 0,
#      'neutralMinionsKilled': 184,
#      'nexusKills': 0,
#      'nexusLost': 0,
#      'nexusTakedowns': 1,
#      'objectivesStolen': 0,
#      'objectivesStolenAssists': 0,
#      'onMyWayPings': 37,
#      'participantId': 2,
#      'pentaKills': 0,
#      'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#       'styles': [{'description': 'primaryStyle',
#         'selections': [{'perk': 9923, 'var1': 82, 'var2': 80, 'var3': 0},
#          {'perk': 8143, 'var1': 2814, 'var2': 0, 'var3': 0},
#          {'perk': 8138, 'var1': 18, 'var2': 0, 'var3': 0},
#          {'perk': 8135, 'var1': 550, 'var2': 5, 'var3': 0}],
#         'style': 8100},
#        {'description': 'subStyle',
#         'selections': [{'perk': 8234, 'var1': 26265, 'var2': 0, 'var3': 0},
#          {'perk': 8232, 'var1': 6, 'var2': 20, 'var3': 0}],
#         'style': 8200}]},
#      'physicalDamageDealt': 327700,
#      'physicalDamageDealtToChampions': 58086,
#      'physicalDamageTaken': 27487,
#      'profileIcon': 27,
#      'pushPings': 0,
#      'puuid': '83KP2e3aQq2wUYj_cbzEv7yKJ1EzJR549Nv3zkcBjv5-0wJGGse2Me9Quzc03c6JruB-zJvRh0aX6A',
#      'quadraKills': 0,
#      'riotIdName': '',
#      'riotIdTagline': '',
#      'role': 'NONE',
#      'sightWardsBoughtInGame': 0,
#      'spell1Casts': 215,
#      'spell2Casts': 120,
#      'spell3Casts': 273,
#      'spell4Casts': 125,
#      'summoner1Casts': 7,
#      'summoner1Id': 4,
#      'summoner2Casts': 29,
#      'summoner2Id': 11,
#      'summonerId': 'ldlcdw4-b8FhwY8ZZS9TRgJTTED4jlosFuv7xr9mcMEmqHHC5JVuRwMW7g',
#      'summonerLevel': 102,
#      'summonerName': 'ComeYoungOne',
#      'teamEarlySurrendered': False,
#      'teamId': 100,
#      'teamPosition': 'JUNGLE',
#      'timeCCingOthers': 50,
#      'timePlayed': 2809,
#      'totalDamageDealt': 476818,
#      'totalDamageDealtToChampions': 77208,
#      'totalDamageShieldedOnTeammates': 0,
#      'totalDamageTaken': 66379,
#      'totalHeal': 19924,
#      'totalHealsOnTeammates': 0,
#      'totalMinionsKilled': 138,
#      'totalTimeCCDealt': 2291,
#      'totalTimeSpentDead': 209,
#      'totalUnitsHealed': 1,
#      'tripleKills': 1,
#      'trueDamageDealt': 56836,
#      'trueDamageDealtToChampions': 8295,
#      'trueDamageTaken': 13583,
#      'turretKills': 1,
#      'turretTakedowns': 3,
#      'turretsLost': 10,
#      'unrealKills': 0,
#      'visionClearedPings': 0,
#      'visionScore': 24,
#      'visionWardsBoughtInGame': 3,
#      'wardsKilled': 3,
#      'wardsPlaced': 3,
#      'win': True},
#     {'allInPings': 2,
#      'assistMePings': 4,
#      'assists': 5,
#      'baitPings': 1,
#      'baronKills': 0,
#      'basicPings': 0,
#      'bountyLevel': 3,
#      'challenges': {'12AssistStreakCount': 0,
#       'abilityUses': 643,
#       'acesBefore15Minutes': 0,
#       'alliedJungleMonsterKills': 14.100000023841858,
#       'baronBuffGoldAdvantageOverThreshold': 1,
#       'baronTakedowns': 0,
#       'blastConeOppositeOpponentCount': 0,
#       'bountyGold': 600,
#       'buffsStolen': 0,
#       'completeSupportQuestInTime': 0,
#       'controlWardTimeCoverageInRiverOrEnemyHalf': 0.036274493018820644,
#       'controlWardsPlaced': 3,
#       'damagePerMinute': 821.1902871761586,
#       'damageTakenOnTeamPercentage': 0.2169664655089643,
#       'dancedWithRiftHerald': 0,
#       'deathsByEnemyChamps': 14,
#       'dodgeSkillShotsSmallWindow': 96,
#       'doubleAces': 0,
#       'dragonTakedowns': 2,
#       'earliestBaron': 2048.992109979023,
#       'earliestDragonTakedown': 367.22768422277113,
#       'earliestElderDragon': 2748.92878605061,
#       'earlyLaningPhaseGoldExpAdvantage': 0,
#       'effectiveHealAndShielding': 0,
#       'elderDragonKillsWithOpposingSoul': 0,
#       'elderDragonMultikills': 0,
#       'enemyChampionImmobilizations': 31,
#       'enemyJungleMonsterKills': 9.300000011920929,
#       'epicMonsterKillsNearEnemyJungler': 0,
#       'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#       'epicMonsterSteals': 0,
#       'epicMonsterStolenWithoutSmite': 0,
#       'flawlessAces': 0,
#       'fullTeamTakedown': 0,
#       'gameLength': 2809.272754470758,
#       'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#       'goldPerMinute': 435.7974373400216,
#       'hadOpenNexus': 0,
#       'immobilizeAndKillWithAlly': 4,
#       'initialBuffCount': 0,
#       'initialCrabCount': 0,
#       'jungleCsBefore10Minutes': 0,
#       'junglerTakedownsNearDamagedEpicMonster': 0,
#       'kTurretsDestroyedBeforePlatesFall': 0,
#       'kda': 1.0714285714285714,
#       'killAfterHiddenWithAlly': 1,
#       'killParticipation': 0.2777777777777778,
#       'killedChampTookFullTeamDamageSurvived': 0,
#       'killingSprees': 2,
#       'killsNearEnemyTurret': 1,
#       'killsOnOtherLanesEarlyJungleAsLaner': 0,
#       'killsOnRecentlyHealedByAramPack': 0,
#       'killsUnderOwnTurret': 1,
#       'killsWithHelpFromEpicMonster': 0,
#       'knockEnemyIntoTeamAndKill': 0,
#       'landSkillShotsEarlyGame': 2,
#       'laneMinionsFirst10Minutes': 68,
#       'laningPhaseGoldExpAdvantage': 0,
#       'legendaryCount': 0,
#       'lostAnInhibitor': 1,
#       'maxCsAdvantageOnLaneOpponent': 137.80000001192093,
#       'maxKillDeficit': 8,
#       'maxLevelLeadLaneOpponent': 1,
#       'moreEnemyJungleThanOpponent': 0,
#       'multiKillOneSpell': 0,
#       'multiTurretRiftHeraldCount': 0,
#       'multikills': 1,
#       'multikillsAfterAggressiveFlash': 0,
#       'mythicItemUsed': 6671,
#       'outerTurretExecutesBefore10Minutes': 0,
#       'outnumberedKills': 6,
#       'outnumberedNexusKill': 0,
#       'perfectDragonSoulsTaken': 0,
#       'perfectGame': 0,
#       'pickKillWithAlly': 11,
#       'playedChampSelectPosition': 1,
#       'poroExplosions': 0,
#       'quickCleanse': 0,
#       'quickFirstTurret': 0,
#       'quickSoloKills': 0,
#       'riftHeraldTakedowns': 1,
#       'saveAllyFromDeath': 0,
#       'scuttleCrabKills': 0,
#       'skillshotsDodged': 485,
#       'skillshotsHit': 22,
#       'snowballsHit': 0,
#       'soloBaronKills': 0,
#       'soloKills': 4,
#       'stealthWardsPlaced': 10,
#       'survivedSingleDigitHpCount': 1,
#       'survivedThreeImmobilizesInFight': 0,
#       'takedownOnFirstTurret': 0,
#       'takedowns': 15,
#       'takedownsAfterGainingLevelAdvantage': 0,
#       'takedownsBeforeJungleMinionSpawn': 0,
#       'takedownsFirstXMinutes': 3,
#       'takedownsInAlcove': 0,
#       'takedownsInEnemyFountain': 0,
#       'teamBaronKills': 2,
#       'teamDamagePercentage': 0.1929737428224052,
#       'teamElderDragonKills': 1,
#       'teamRiftHeraldKills': 2,
#       'threeWardsOneSweeperCount': 0,
#       'tookLargeDamageSurvived': 0,
#       'turretPlatesTaken': 2,
#       'turretTakedowns': 0,
#       'turretsTakenWithRiftHerald': 5,
#       'twentyMinionsIn3SecondsCount': 15,
#       'unseenRecalls': 0,
#       'visionScoreAdvantageLaneOpponent': -0.34200620651245117,
#       'visionScorePerMinute': 0.49362615184328223,
#       'wardTakedowns': 1,
#       'wardTakedownsBefore20M': 1,
#       'wardsGuarded': 0},
#      'champExperience': 27871,
#      'champLevel': 18,
#      'championId': 157,
#      'championName': 'Yasuo',
#      'championTransform': 0,
#      'commandPings': 6,
#      'consumablesPurchased': 4,
#      'damageDealtToBuildings': 2455,
#      'damageDealtToObjectives': 20788,
#      'damageDealtToTurrets': 2455,
#      'damageSelfMitigated': 74968,
#      'dangerPings': 0,
#      'deaths': 14,
#      'detectorWardsPlaced': 3,
#      'doubleKills': 1,
#      'dragonKills': 0,
#      'eligibleForProgression': True,
#      'enemyMissingPings': 1,
#      'enemyVisionPings': 2,
#      'firstBloodAssist': False,
#      'firstBloodKill': True,
#      'firstTowerAssist': False,
#      'firstTowerKill': False,
#      'gameEndedInEarlySurrender': False,
#      'gameEndedInSurrender': False,
#      'getBackPings': 1,
#      'goldEarned': 20404,
#      'goldSpent': 18475,
#      'holdPings': 0,
#      'individualPosition': 'MIDDLE',
#      'inhibitorKills': 0,
#      'inhibitorTakedowns': 0,
#      'inhibitorsLost': 5,
#      'item0': 6671,
#      'item1': 3006,
#      'item2': 3031,
#      'item3': 3153,
#      'item4': 3156,
#      'item5': 6333,
#      'item6': 3340,
#      'itemsPurchased': 27,
#      'killingSprees': 3,
#      'kills': 10,
#      'lane': 'MIDDLE',
#      'largestCriticalStrike': 913,
#      'largestKillingSpree': 3,
#      'largestMultiKill': 2,
#      'longestTimeSpentLiving': 438,
#      'magicDamageDealt': 27515,
#      'magicDamageDealtToChampions': 4158,
#      'magicDamageTaken': 12607,
#      'needVisionPings': 0,
#      'neutralMinionsKilled': 26,
#      'nexusKills': 0,
#      'nexusLost': 0,
#      'nexusTakedowns': 0,
#      'objectivesStolen': 0,
#      'objectivesStolenAssists': 0,
#      'onMyWayPings': 4,
#      'participantId': 3,
#      'pentaKills': 0,
#      'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#       'styles': [{'description': 'primaryStyle',
#         'selections': [{'perk': 8008, 'var1': 77, 'var2': 7, 'var3': 0},
#          {'perk': 9111, 'var1': 1292, 'var2': 300, 'var3': 0},
#          {'perk': 9104, 'var1': 15, 'var2': 10, 'var3': 0},
#          {'perk': 8014, 'var1': 991, 'var2': 0, 'var3': 0}],
#         'style': 8000},
#        {'description': 'subStyle',
#         'selections': [{'perk': 8429, 'var1': 74, 'var2': 13, 'var3': 11},
#          {'perk': 8242, 'var1': 163, 'var2': 0, 'var3': 0}],
#         'style': 8400}]},
#      'physicalDamageDealt': 353517,
#      'physicalDamageDealtToChampions': 30351,
#      'physicalDamageTaken': 33564,
#      'profileIcon': 3546,
#      'pushPings': 0,
#      'puuid': 'DexOCDO001rqCT4u392-vxNQt4evAJE7bE4Va7x5NcQZ4zDcW0EgBhuQghd45FiYfC03oF-CvCA68Q',
#      'quadraKills': 0,
#      'riotIdName': '',
#      'riotIdTagline': '',
#      'role': 'CARRY',
#      'sightWardsBoughtInGame': 0,
#      'spell1Casts': 395,
#      'spell2Casts': 14,
#      'spell3Casts': 225,
#      'spell4Casts': 9,
#      'summoner1Casts': 8,
#      'summoner1Id': 14,
#      'summoner2Casts': 8,
#      'summoner2Id': 4,
#      'summonerId': 'zQkeBjRVbXDIlKo40RsjK80cizwtsiTXpImxRGhKHpvh6N1z_9hFxn5T3Q',
#      'summonerLevel': 54,
#      'summonerName': 'epnpj',
#      'teamEarlySurrendered': False,
#      'teamId': 100,
#      'teamPosition': 'MIDDLE',
#      'timeCCingOthers': 30,
#      'timePlayed': 2809,
#      'totalDamageDealt': 397647,
#      'totalDamageDealtToChampions': 38449,
#      'totalDamageShieldedOnTeammates': 0,
#      'totalDamageTaken': 52194,
#      'totalHeal': 7244,
#      'totalHealsOnTeammates': 0,
#      'totalMinionsKilled': 325,
#      'totalTimeCCDealt': 230,
#      'totalTimeSpentDead': 651,
#      'totalUnitsHealed': 1,
#      'tripleKills': 0,
#      'trueDamageDealt': 16615,
#      'trueDamageDealtToChampions': 3939,
#      'trueDamageTaken': 6022,
#      'turretKills': 0,
#      'turretTakedowns': 0,
#      'turretsLost': 10,
#      'unrealKills': 0,
#      'visionClearedPings': 0,
#      'visionScore': 23,
#      'visionWardsBoughtInGame': 3,
#      'wardsKilled': 1,
#      'wardsPlaced': 13,
#      'win': True},
#     {'allInPings': 0,
#      'assistMePings': 0,
#      'assists': 11,
#      'baitPings': 0,
#      'baronKills': 0,
#      'basicPings': 0,
#      'bountyLevel': 3,
#      'challenges': {'12AssistStreakCount': 0,
#       'abilityUses': 377,
#       'acesBefore15Minutes': 0,
#       'alliedJungleMonsterKills': 19.400000035762787,
#       'baronBuffGoldAdvantageOverThreshold': 1,
#       'baronTakedowns': 1,
#       'blastConeOppositeOpponentCount': 0,
#       'bountyGold': 500,
#       'buffsStolen': 1,
#       'completeSupportQuestInTime': 0,
#       'controlWardsPlaced': 0,
#       'damagePerMinute': 1054.4169065769627,
#       'damageTakenOnTeamPercentage': 0.12700774963800657,
#       'dancedWithRiftHerald': 0,
#       'deathsByEnemyChamps': 6,
#       'dodgeSkillShotsSmallWindow': 8,
#       'doubleAces': 0,
#       'dragonTakedowns': 2,
#       'earliestBaron': 2048.992109979023,
#       'earliestDragonTakedown': 1707.7988396290036,
#       'earliestElderDragon': 2748.92878605061,
#       'earlyLaningPhaseGoldExpAdvantage': 0,
#       'effectiveHealAndShielding': 1285.1859130859375,
#       'elderDragonKillsWithOpposingSoul': 0,
#       'elderDragonMultikills': 0,
#       'enemyChampionImmobilizations': 0,
#       'enemyJungleMonsterKills': 8,
#       'epicMonsterKillsNearEnemyJungler': 2,
#       'epicMonsterKillsWithin30SecondsOfSpawn': 2,
#       'epicMonsterSteals': 1,
#       'epicMonsterStolenWithoutSmite': 1,
#       'flawlessAces': 0,
#       'fullTeamTakedown': 0,
#       'gameLength': 2809.272754470758,
#       'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#       'goldPerMinute': 476.3197269188226,
#       'hadOpenNexus': 0,
#       'immobilizeAndKillWithAlly': 0,
#       'initialBuffCount': 0,
#       'initialCrabCount': 0,
#       'jungleCsBefore10Minutes': 0,
#       'junglerTakedownsNearDamagedEpicMonster': 0,
#       'kTurretsDestroyedBeforePlatesFall': 0,
#       'kda': 3.6666666666666665,
#       'killAfterHiddenWithAlly': 2,
#       'killParticipation': 0.4074074074074074,
#       'killedChampTookFullTeamDamageSurvived': 0,
#       'killingSprees': 2,
#       'killsNearEnemyTurret': 2,
#       'killsOnOtherLanesEarlyJungleAsLaner': 0,
#       'killsOnRecentlyHealedByAramPack': 0,
#       'killsUnderOwnTurret': 1,
#       'killsWithHelpFromEpicMonster': 0,
#       'knockEnemyIntoTeamAndKill': 0,
#       'landSkillShotsEarlyGame': 0,
#       'laneMinionsFirst10Minutes': 48,
#       'laningPhaseGoldExpAdvantage': 0,
#       'legendaryCount': 0,
#       'lostAnInhibitor': 1,
#       'maxCsAdvantageOnLaneOpponent': 80.00000002980232,
#       'maxKillDeficit': 8,
#       'maxLevelLeadLaneOpponent': 1,
#       'moreEnemyJungleThanOpponent': 0,
#       'multiKillOneSpell': 0,
#       'multiTurretRiftHeraldCount': 0,
#       'multikills': 2,
#       'multikillsAfterAggressiveFlash': 0,
#       'mythicItemUsed': 6692,
#       'outerTurretExecutesBefore10Minutes': 0,
#       'outnumberedKills': 1,
#       'outnumberedNexusKill': 0,
#       'perfectDragonSoulsTaken': 0,
#       'perfectGame': 0,
#       'pickKillWithAlly': 21,
#       'playedChampSelectPosition': 1,
#       'poroExplosions': 0,
#       'quickCleanse': 0,
#       'quickFirstTurret': 0,
#       'quickSoloKills': 1,
#       'riftHeraldTakedowns': 0,
#       'saveAllyFromDeath': 0,
#       'scuttleCrabKills': 1,
#       'skillshotsDodged': 49,
#       'skillshotsHit': 0,
#       'snowballsHit': 0,
#       'soloBaronKills': 0,
#       'soloKills': 0,
#       'soloTurretsLategame': 1,
#       'stealthWardsPlaced': 17,
#       'survivedSingleDigitHpCount': 0,
#       'survivedThreeImmobilizesInFight': 0,
#       'takedownOnFirstTurret': 0,
#       'takedowns': 22,
#       'takedownsAfterGainingLevelAdvantage': 0,
#       'takedownsBeforeJungleMinionSpawn': 0,
#       'takedownsFirstXMinutes': 4,
#       'takedownsInAlcove': 0,
#       'takedownsInEnemyFountain': 1,
#       'teamBaronKills': 2,
#       'teamDamagePercentage': 0.24778030151461133,
#       'teamElderDragonKills': 1,
#       'teamRiftHeraldKills': 2,
#       'threeWardsOneSweeperCount': 0,
#       'tookLargeDamageSurvived': 0,
#       'turretPlatesTaken': 0,
#       'turretTakedowns': 5,
#       'turretsTakenWithRiftHerald': 5,
#       'twentyMinionsIn3SecondsCount': 14,
#       'unseenRecalls': 0,
#       'visionScoreAdvantageLaneOpponent': -0.2702401280403137,
#       'visionScorePerMinute': 0.5402919224926883,
#       'wardTakedowns': 0,
#       'wardTakedownsBefore20M': 0,
#       'wardsGuarded': 0},
#      'champExperience': 26398,
#      'champLevel': 18,
#      'championId': 21,
#      'championName': 'MissFortune',
#      'championTransform': 0,
#      'commandPings': 3,
#      'consumablesPurchased': 3,
#      'damageDealtToBuildings': 7948,
#      'damageDealtToObjectives': 31419,
#      'damageDealtToTurrets': 7948,
#      'damageSelfMitigated': 19643,
#      'dangerPings': 0,
#      'deaths': 6,
#      'detectorWardsPlaced': 0,
#      'doubleKills': 2,
#      'dragonKills': 2,
#      'eligibleForProgression': True,
#      'enemyMissingPings': 1,
#      'enemyVisionPings': 0,
#      'firstBloodAssist': False,
#      'firstBloodKill': False,
#      'firstTowerAssist': False,
#      'firstTowerKill': False,
#      'gameEndedInEarlySurrender': False,
#      'gameEndedInSurrender': False,
#      'getBackPings': 0,
#      'goldEarned': 22301,
#      'goldSpent': 20300,
#      'holdPings': 0,
#      'individualPosition': 'BOTTOM',
#      'inhibitorKills': 1,
#      'inhibitorTakedowns': 1,
#      'inhibitorsLost': 5,
#      'item0': 3031,
#      'item1': 6692,
#      'item2': 3508,
#      'item3': 3095,
#      'item4': 6676,
#      'item5': 3036,
#      'item6': 3340,
#      'itemsPurchased': 27,
#      'killingSprees': 3,
#      'kills': 11,
#      'lane': 'BOTTOM',
#      'largestCriticalStrike': 1321,
#      'largestKillingSpree': 4,
#      'largestMultiKill': 2,
#      'longestTimeSpentLiving': 991,
#      'magicDamageDealt': 26318,
#      'magicDamageDealtToChampions': 3748,
#      'magicDamageTaken': 10478,
#      'needVisionPings': 0,
#      'neutralMinionsKilled': 42,
#      'nexusKills': 0,
#      'nexusLost': 0,
#      'nexusTakedowns': 1,
#      'objectivesStolen': 1,
#      'objectivesStolenAssists': 0,
#      'onMyWayPings': 1,
#      'participantId': 4,
#      'pentaKills': 0,
#      'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#       'styles': [{'description': 'primaryStyle',
#         'selections': [{'perk': 8005,
#           'var1': 2216,
#           'var2': 1104,
#           'var3': 1112},
#          {'perk': 8009, 'var1': 2709, 'var2': 0, 'var3': 0},
#          {'perk': 9103, 'var1': 28, 'var2': 20, 'var3': 0},
#          {'perk': 8014, 'var1': 1268, 'var2': 0, 'var3': 0}],
#         'style': 8000},
#        {'description': 'subStyle',
#         'selections': [{'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#          {'perk': 8304, 'var1': 9, 'var2': 4, 'var3': 5}],
#         'style': 8300}]},
#      'physicalDamageDealt': 364469,
#      'physicalDamageDealtToChampions': 39974,
#      'physicalDamageTaken': 18183,
#      'profileIcon': 4928,
#      'pushPings': 0,
#      'puuid': 'ZRHt3hu1ECYzkMsZlWFHI376PAnBtso5_OrHVxe4hPr4YD6lHLrGBUKWM5KqHRXoZrRtZttCBBuBSA',
#      'quadraKills': 0,
#      'riotIdName': '',
#      'riotIdTagline': '',
#      'role': 'SOLO',
#      'sightWardsBoughtInGame': 0,
#      'spell1Casts': 169,
#      'spell2Casts': 91,
#      'spell3Casts': 99,
#      'spell4Casts': 18,
#      'summoner1Casts': 6,
#      'summoner1Id': 4,
#      'summoner2Casts': 7,
#      'summoner2Id': 7,
#      'summonerId': 'nxTbS8nay0BgwOAB9uR-3XcbpV1tPVyvH-Pu8bPFvdC8zqyx1Nnf0-PIJA',
#      'summonerLevel': 283,
#      'summonerName': 'lJackFrost',
#      'teamEarlySurrendered': False,
#      'teamId': 100,
#      'teamPosition': 'BOTTOM',
#      'timeCCingOthers': 15,
#      'timePlayed': 2809,
#      'totalDamageDealt': 397611,
#      'totalDamageDealtToChampions': 49369,
#      'totalDamageShieldedOnTeammates': 0,
#      'totalDamageTaken': 30553,
#      'totalHeal': 12605,
#      'totalHealsOnTeammates': 1285,
#      'totalMinionsKilled': 298,
#      'totalTimeCCDealt': 498,
#      'totalTimeSpentDead': 238,
#      'totalUnitsHealed': 4,
#      'tripleKills': 0,
#      'trueDamageDealt': 6823,
#      'trueDamageDealtToChampions': 5645,
#      'trueDamageTaken': 1890,
#      'turretKills': 3,
#      'turretTakedowns': 5,
#      'turretsLost': 10,
#      'unrealKills': 0,
#      'visionClearedPings': 0,
#      'visionScore': 25,
#      'visionWardsBoughtInGame': 0,
#      'wardsKilled': 0,
#      'wardsPlaced': 17,
#      'win': True},
#     {'allInPings': 0,
#      'assistMePings': 11,
#      'assists': 32,
#      'baitPings': 0,
#      'baronKills': 0,
#      'basicPings': 0,
#      'bountyLevel': 0,
#      'challenges': {'12AssistStreakCount': 2,
#       'abilityUses': 236,
#       'acesBefore15Minutes': 0,
#       'alliedJungleMonsterKills': 0,
#       'baronBuffGoldAdvantageOverThreshold': 1,
#       'baronTakedowns': 2,
#       'blastConeOppositeOpponentCount': 0,
#       'bountyGold': 0,
#       'buffsStolen': 0,
#       'completeSupportQuestInTime': 0,
#       'controlWardsPlaced': 4,
#       'damagePerMinute': 323.87705427571035,
#       'damageTakenOnTeamPercentage': 0.17562038924516343,
#       'dancedWithRiftHerald': 0,
#       'deathsByEnemyChamps': 11,
#       'dodgeSkillShotsSmallWindow': 44,
#       'doubleAces': 0,
#       'dragonTakedowns': 3,
#       'earliestBaron': 2048.992109979023,
#       'earliestDragonTakedown': 367.22768422277113,
#       'earliestElderDragon': 2748.92878605061,
#       'earlyLaningPhaseGoldExpAdvantage': 0,
#       'effectiveHealAndShielding': 1158.45654296875,
#       'elderDragonKillsWithOpposingSoul': 0,
#       'elderDragonMultikills': 0,
#       'enemyChampionImmobilizations': 105,
#       'enemyJungleMonsterKills': 0,
#       'epicMonsterKillsNearEnemyJungler': 0,
#       'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#       'epicMonsterSteals': 0,
#       'epicMonsterStolenWithoutSmite': 0,
#       'fasterSupportQuestCompletion': 1,
#       'flawlessAces': 0,
#       'fullTeamTakedown': 0,
#       'gameLength': 2809.272754470758,
#       'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#       'goldPerMinute': 286.37345770838505,
#       'hadOpenNexus': 0,
#       'highestWardKills': 1,
#       'immobilizeAndKillWithAlly': 25,
#       'initialBuffCount': 0,
#       'initialCrabCount': 0,
#       'jungleCsBefore10Minutes': 0,
#       'junglerTakedownsNearDamagedEpicMonster': 0,
#       'kTurretsDestroyedBeforePlatesFall': 0,
#       'kda': 3.090909090909091,
#       'killAfterHiddenWithAlly': 9,
#       'killParticipation': 0.6296296296296297,
#       'killedChampTookFullTeamDamageSurvived': 0,
#       'killsNearEnemyTurret': 1,
#       'killsOnOtherLanesEarlyJungleAsLaner': 0,
#       'killsOnRecentlyHealedByAramPack': 0,
#       'killsUnderOwnTurret': 0,
#       'killsWithHelpFromEpicMonster': 1,
#       'knockEnemyIntoTeamAndKill': 0,
#       'landSkillShotsEarlyGame': 6,
#       'laneMinionsFirst10Minutes': 7,
#       'laningPhaseGoldExpAdvantage': 0,
#       'legendaryCount': 0,
#       'lostAnInhibitor': 1,
#       'maxCsAdvantageOnLaneOpponent': 9,
#       'maxKillDeficit': 8,
#       'maxLevelLeadLaneOpponent': 2,
#       'moreEnemyJungleThanOpponent': 0,
#       'multiKillOneSpell': 0,
#       'multiTurretRiftHeraldCount': 0,
#       'multikills': 0,
#       'multikillsAfterAggressiveFlash': 0,
#       'mythicItemUsed': 3190,
#       'outerTurretExecutesBefore10Minutes': 0,
#       'outnumberedKills': 0,
#       'outnumberedNexusKill': 0,
#       'perfectDragonSoulsTaken': 0,
#       'perfectGame': 0,
#       'pickKillWithAlly': 33,
#       'playedChampSelectPosition': 1,
#       'poroExplosions': 0,
#       'quickCleanse': 0,
#       'quickFirstTurret': 0,
#       'quickSoloKills': 0,
#       'riftHeraldTakedowns': 0,
#       'saveAllyFromDeath': 0,
#       'scuttleCrabKills': 0,
#       'shortestTimeToAceFromFirstTakedown': 48.08784818922982,
#       'skillshotsDodged': 226,
#       'skillshotsHit': 44,
#       'snowballsHit': 0,
#       'soloBaronKills': 0,
#       'soloKills': 0,
#       'stealthWardsPlaced': 45,
#       'survivedSingleDigitHpCount': 0,
#       'survivedThreeImmobilizesInFight': 0,
#       'takedownOnFirstTurret': 0,
#       'takedowns': 34,
#       'takedownsAfterGainingLevelAdvantage': 0,
#       'takedownsBeforeJungleMinionSpawn': 0,
#       'takedownsFirstXMinutes': 8,
#       'takedownsInAlcove': 1,
#       'takedownsInEnemyFountain': 0,
#       'teamBaronKills': 2,
#       'teamDamagePercentage': 0.07610875135018723,
#       'teamElderDragonKills': 1,
#       'teamRiftHeraldKills': 2,
#       'threeWardsOneSweeperCount': 0,
#       'tookLargeDamageSurvived': 0,
#       'turretPlatesTaken': 0,
#       'turretTakedowns': 2,
#       'turretsTakenWithRiftHerald': 5,
#       'twentyMinionsIn3SecondsCount': 0,
#       'unseenRecalls': 0,
#       'visionScoreAdvantageLaneOpponent': 0.2056344747543335,
#       'visionScorePerMinute': 2.421583532795492,
#       'wardTakedowns': 10,
#       'wardTakedownsBefore20M': 3,
#       'wardsGuarded': 0},
#      'champExperience': 21852,
#      'champLevel': 18,
#      'championId': 89,
#      'championName': 'Leona',
#      'championTransform': 0,
#      'commandPings': 9,
#      'consumablesPurchased': 7,
#      'damageDealtToBuildings': 0,
#      'damageDealtToObjectives': 3712,
#      'damageDealtToTurrets': 0,
#      'damageSelfMitigated': 59386,
#      'dangerPings': 0,
#      'deaths': 11,
#      'detectorWardsPlaced': 4,
#      'doubleKills': 0,
#      'dragonKills': 0,
#      'eligibleForProgression': True,
#      'enemyMissingPings': 3,
#      'enemyVisionPings': 0,
#      'firstBloodAssist': False,
#      'firstBloodKill': False,
#      'firstTowerAssist': False,
#      'firstTowerKill': False,
#      'gameEndedInEarlySurrender': False,
#      'gameEndedInSurrender': False,
#      'getBackPings': 0,
#      'goldEarned': 13408,
#      'goldSpent': 11500,
#      'holdPings': 0,
#      'individualPosition': 'UTILITY',
#      'inhibitorKills': 0,
#      'inhibitorTakedowns': 0,
#      'inhibitorsLost': 5,
#      'item0': 3860,
#      'item1': 3190,
#      'item2': 3050,
#      'item3': 3075,
#      'item4': 3111,
#      'item5': 3109,
#      'item6': 3364,
#      'itemsPurchased': 31,
#      'killingSprees': 1,
#      'kills': 2,
#      'lane': 'MIDDLE',
#      'largestCriticalStrike': 21,
#      'largestKillingSpree': 2,
#      'largestMultiKill': 1,
#      'longestTimeSpentLiving': 496,
#      'magicDamageDealt': 18697,
#      'magicDamageDealtToChampions': 7758,
#      'magicDamageTaken': 14739,
#      'needVisionPings': 0,
#      'neutralMinionsKilled': 0,
#      'nexusKills': 0,
#      'nexusLost': 0,
#      'nexusTakedowns': 1,
#      'objectivesStolen': 0,
#      'objectivesStolenAssists': 0,
#      'onMyWayPings': 16,
#      'participantId': 5,
#      'pentaKills': 0,
#      'perks': {'statPerks': {'defense': 5001, 'flex': 5002, 'offense': 5007},
#       'styles': [{'description': 'primaryStyle',
#         'selections': [{'perk': 8351, 'var1': 97, 'var2': 1272, 'var3': 0},
#          {'perk': 8304, 'var1': 9, 'var2': 0, 'var3': 0},
#          {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#          {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#         'style': 8300},
#        {'description': 'subStyle',
#         'selections': [{'perk': 8473, 'var1': 1665, 'var2': 0, 'var3': 0},
#          {'perk': 8242, 'var1': 95, 'var2': 0, 'var3': 0}],
#         'style': 8400}]},
#      'physicalDamageDealt': 11094,
#      'physicalDamageDealtToChampions': 3954,
#      'physicalDamageTaken': 21755,
#      'profileIcon': 4887,
#      'pushPings': 0,
#      'puuid': 'mOkgOSPnkqSYHgqS1arfKJ1yzOApIdKM9F7Cx-AEA3lvwCMt1c6VTuINXBd8zM2tjdVRVqtNs2qo3g',
#      'quadraKills': 0,
#      'riotIdName': '',
#      'riotIdTagline': '',
#      'role': 'SUPPORT',
#      'sightWardsBoughtInGame': 0,
#      'spell1Casts': 103,
#      'spell2Casts': 51,
#      'spell3Casts': 62,
#      'spell4Casts': 20,
#      'summoner1Casts': 8,
#      'summoner1Id': 4,
#      'summoner2Casts': 11,
#      'summoner2Id': 14,
#      'summonerId': 'WlNyhKKOA5_ImfA227XYBMv8HxUkLAslK6gb56dEWLGRI4uV',
#      'summonerLevel': 299,
#      'summonerName': 'KebabasSuMixu1',
#      'teamEarlySurrendered': False,
#      'teamId': 100,
#      'teamPosition': 'UTILITY',
#      'timeCCingOthers': 93,
#      'timePlayed': 2809,
#      'totalDamageDealt': 40160,
#      'totalDamageDealtToChampions': 15164,
#      'totalDamageShieldedOnTeammates': 1158,
#      'totalDamageTaken': 42248,
#      'totalHeal': 9741,
#      'totalHealsOnTeammates': 0,
#      'totalMinionsKilled': 30,
#      'totalTimeCCDealt': 317,
#      'totalTimeSpentDead': 345,
#      'totalUnitsHealed': 1,
#      'tripleKills': 0,
#      'trueDamageDealt': 10368,
#      'trueDamageDealtToChampions': 3451,
#      'trueDamageTaken': 5753,
#      'turretKills': 0,
#      'turretTakedowns': 2,
#      'turretsLost': 10,
#      'unrealKills': 0,
#      'visionClearedPings': 0,
#      'visionScore': 113,
#      'visionWardsBoughtInGame': 4,
#      'wardsKilled': 10,
#      'wardsPlaced': 49,
#      'win': True},
#     {'allInPings': 0,
#      'assistMePings': 5,
#      'assists': 8,
#      'baitPings': 1,
#      'baronKills': 0,
#      'basicPings': 0,
#      'bountyLevel': 0,
#      'challenges': {'12AssistStreakCount': 0,
#       'abilityUses': 376,
#       'acesBefore15Minutes': 0,
#       'alliedJungleMonsterKills': 4,
#       'baronTakedowns': 1,
#       'blastConeOppositeOpponentCount': 0,
#       'bountyGold': 525,
#       'buffsStolen': 1,
#       'completeSupportQuestInTime': 0,
#       'controlWardsPlaced': 0,
#       'damagePerMinute': 972.2562133841499,
#       'damageTakenOnTeamPercentage': 0.2796461613831727,
#       'dancedWithRiftHerald': 0,
#       'deathsByEnemyChamps': 11,
#       'dodgeSkillShotsSmallWindow': 9,
#       'doubleAces': 0,
#       'dragonTakedowns': 1,
#       'earliestBaron': 1656.809827495364,
#       'earliestDragonTakedown': 1395.2248521024976,
#       'earlyLaningPhaseGoldExpAdvantage': 1,
#       'effectiveHealAndShielding': 760.4627075195312,
#       'elderDragonKillsWithOpposingSoul': 0,
#       'elderDragonMultikills': 0,
#       'enemyChampionImmobilizations': 5,
#       'enemyJungleMonsterKills': 4,
#       'epicMonsterKillsNearEnemyJungler': 0,
#       'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#       'epicMonsterSteals': 0,
#       'epicMonsterStolenWithoutSmite': 0,
#       'firstTurretKilledTime': 981.2803422721892,
#       'flawlessAces': 0,
#       'fullTeamTakedown': 1,
#       'gameLength': 2809.272754470758,
#       'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#       'goldPerMinute': 404.641645490259,
#       'hadOpenNexus': 0,
#       'immobilizeAndKillWithAlly': 1,
#       'initialBuffCount': 0,
#       'initialCrabCount': 0,
#       'jungleCsBefore10Minutes': 0,
#       'junglerTakedownsNearDamagedEpicMonster': 0,
#       'kTurretsDestroyedBeforePlatesFall': 0,
#       'kda': 1.8181818181818181,
#       'killAfterHiddenWithAlly': 1,
#       'killParticipation': 0.4166666666666667,
#       'killedChampTookFullTeamDamageSurvived': 0,
#       'killingSprees': 2,
#       'killsNearEnemyTurret': 2,
#       'killsOnOtherLanesEarlyJungleAsLaner': 0,
#       'killsOnRecentlyHealedByAramPack': 0,
#       'killsUnderOwnTurret': 0,
#       'killsWithHelpFromEpicMonster': 0,
#       'knockEnemyIntoTeamAndKill': 0,
#       'landSkillShotsEarlyGame': 2,
#       'laneMinionsFirst10Minutes': 58,
#       'laningPhaseGoldExpAdvantage': 1,
#       'legendaryCount': 0,
#       'lostAnInhibitor': 0,
#       'maxCsAdvantageOnLaneOpponent': 66,
#       'maxKillDeficit': 0,
#       'maxLevelLeadLaneOpponent': 3,
#       'moreEnemyJungleThanOpponent': 0,
#       'multiKillOneSpell': 0,
#       'multiTurretRiftHeraldCount': 0,
#       'multikills': 2,
#       'multikillsAfterAggressiveFlash': 0,
#       'mythicItemUsed': 6632,
#       'outerTurretExecutesBefore10Minutes': 0,
#       'outnumberedKills': 2,
#       'outnumberedNexusKill': 0,
#       'perfectDragonSoulsTaken': 0,
#       'perfectGame': 0,
#       'pickKillWithAlly': 14,
#       'playedChampSelectPosition': 1,
#       'poroExplosions': 0,
#       'quickCleanse': 0,
#       'quickFirstTurret': 0,
#       'quickSoloKills': 0,
#       'riftHeraldTakedowns': 0,
#       'saveAllyFromDeath': 0,
#       'scuttleCrabKills': 2,
#       'skillshotsDodged': 48,
#       'skillshotsHit': 23,
#       'snowballsHit': 0,
#       'soloBaronKills': 0,
#       'soloKills': 5,
#       'soloTurretsLategame': 3,
#       'stealthWardsPlaced': 11,
#       'survivedSingleDigitHpCount': 0,
#       'survivedThreeImmobilizesInFight': 4,
#       'takedownOnFirstTurret': 0,
#       'takedowns': 20,
#       'takedownsAfterGainingLevelAdvantage': 0,
#       'takedownsBeforeJungleMinionSpawn': 0,
#       'takedownsFirstXMinutes': 4,
#       'takedownsInAlcove': 2,
#       'takedownsInEnemyFountain': 0,
#       'teamBaronKills': 1,
#       'teamDamagePercentage': 0.24650600765595798,
#       'teamElderDragonKills': 0,
#       'teamRiftHeraldKills': 2,
#       'thirdInhibitorDestroyedTime': 2651.970502612013,
#       'threeWardsOneSweeperCount': 0,
#       'tookLargeDamageSurvived': 0,
#       'turretPlatesTaken': 3,
#       'turretTakedowns': 3,
#       'turretsTakenWithRiftHerald': 0,
#       'twentyMinionsIn3SecondsCount': 10,
#       'unseenRecalls': 0,
#       'visionScoreAdvantageLaneOpponent': 0.6810400485992432,
#       'visionScorePerMinute': 0.5369634368304856,
#       'wardTakedowns': 1,
#       'wardTakedownsBefore20M': 1,
#       'wardsGuarded': 0},
#      'champExperience': 23968,
#      'champLevel': 18,
#      'championId': 114,
#      'championName': 'Fiora',
#      'championTransform': 0,
#      'commandPings': 11,
#      'consumablesPurchased': 2,
#      'damageDealtToBuildings': 10185,
#      'damageDealtToObjectives': 20066,
#      'damageDealtToTurrets': 10185,
#      'damageSelfMitigated': 96352,
#      'dangerPings': 0,
#      'deaths': 11,
#      'detectorWardsPlaced': 0,
#      'doubleKills': 2,
#      'dragonKills': 0,
#      'eligibleForProgression': True,
#      'enemyMissingPings': 3,
#      'enemyVisionPings': 0,
#      'firstBloodAssist': False,
#      'firstBloodKill': False,
#      'firstTowerAssist': False,
#      'firstTowerKill': False,
#      'gameEndedInEarlySurrender': False,
#      'gameEndedInSurrender': False,
#      'getBackPings': 10,
#      'goldEarned': 18945,
#      'goldSpent': 18930,
#      'holdPings': 1,
#      'individualPosition': 'TOP',
#      'inhibitorKills': 1,
#      'inhibitorTakedowns': 1,
#      'inhibitorsLost': 1,
#      'item0': 6632,
#      'item1': 3047,
#      'item2': 3074,
#      'item3': 3153,
#      'item4': 6333,
#      'item5': 3026,
#      'item6': 3363,
#      'itemsPurchased': 28,
#      'killingSprees': 4,
#      'kills': 12,
#      'lane': 'TOP',
#      'largestCriticalStrike': 762,
#      'largestKillingSpree': 4,
#      'largestMultiKill': 2,
#      'longestTimeSpentLiving': 905,
#      'magicDamageDealt': 5724,
# ...
#       'controlWardsPlaced': 0,
#       'damagePerMinute': 832.6862097311965,
#       'damageTakenOnTeamPercentage': 0.11999504816400663,
#       'dancedWithRiftHerald': 0,
#       'deathsByEnemyChamps': 9,
#       'dodgeSkillShotsSmallWindow': 3,
#       'doubleAces': 0,
#       'dragonTakedowns': 0,
#       'earlyLaningPhaseGoldExpAdvantage': 0,
#       'effectiveHealAndShielding': 4209.251953125,
#       'elderDragonKillsWithOpposingSoul': 0,
#       'elderDragonMultikills': 0,
#       'enemyChampionImmobilizations': 26,
#       'enemyJungleMonsterKills': 0,
#       'epicMonsterKillsNearEnemyJungler': 0,
#       'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#       'epicMonsterSteals': 0,
#       'epicMonsterStolenWithoutSmite': 0,
#       'flawlessAces': 1,
#       'fullTeamTakedown': 6,
#       'gameLength': 1241.154113019509,
#       'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#       'goldPerMinute': 608.4311593669353,
#       'hadOpenNexus': 0,
#       'immobilizeAndKillWithAlly': 7,
#       'initialBuffCount': 0,
#       'initialCrabCount': 0,
#       'jungleCsBefore10Minutes': 0,
#       'junglerTakedownsNearDamagedEpicMonster': 0,
#       'kTurretsDestroyedBeforePlatesFall': 1,
#       'kda': 3.1,
#       'killAfterHiddenWithAlly': 6,
#       'killParticipation': 0.4626865671641791,
#       'killedChampTookFullTeamDamageSurvived': 0,
#       'killsNearEnemyTurret': 0,
#       'killsOnOtherLanesEarlyJungleAsLaner': 0,
#       'killsOnRecentlyHealedByAramPack': 0,
#       'killsUnderOwnTurret': 0,
#       'killsWithHelpFromEpicMonster': 0,
#       'knockEnemyIntoTeamAndKill': 0,
#       'landSkillShotsEarlyGame': 0,
#       'laneMinionsFirst10Minutes': 4,
#       'laningPhaseGoldExpAdvantage': 0,
#       'legendaryCount': 0,
#       'lostAnInhibitor': 0,
#       'maxCsAdvantageOnLaneOpponent': 1,
#       'maxKillDeficit': 4,
#       'maxLevelLeadLaneOpponent': 2,
#       'moreEnemyJungleThanOpponent': 0,
#       'multiKillOneSpell': 0,
#       'multiTurretRiftHeraldCount': 0,
#       'multikills': 0,
#       'multikillsAfterAggressiveFlash': 0,
#       'mythicItemUsed': 6653,
#       'outerTurretExecutesBefore10Minutes': 0,
#       'outnumberedKills': 0,
#       'outnumberedNexusKill': 0,
#       'perfectDragonSoulsTaken': 0,
#       'perfectGame': 0,
#       'pickKillWithAlly': 25,
#       'poroExplosions': 0,
#       'quickCleanse': 0,
#       'quickFirstTurret': 0,
#       'quickSoloKills': 0,
#       'riftHeraldTakedowns': 0,
#       'saveAllyFromDeath': 0,
#       'scuttleCrabKills': 0,
#       'shortestTimeToAceFromFirstTakedown': 38.711858833386486,
#       'skillshotsDodged': 20,
#       'skillshotsHit': 0,
#       'snowballsHit': 0,
#       'soloBaronKills': 0,
#       'soloKills': 0,
#       'stealthWardsPlaced': 0,
#       'survivedSingleDigitHpCount': 0,
#       'survivedThreeImmobilizesInFight': 0,
#       'takedownOnFirstTurret': 0,
#       'takedowns': 31,
#       'takedownsAfterGainingLevelAdvantage': 0,
#       'takedownsBeforeJungleMinionSpawn': 0,
#       'takedownsFirstXMinutes': 22,
#       'takedownsInAlcove': 0,
#       'takedownsInEnemyFountain': 0,
#       'teamBaronKills': 0,
#       'teamDamagePercentage': 0.10320579421185004,
#       'teamElderDragonKills': 0,
#       'teamRiftHeraldKills': 0,
#       'threeWardsOneSweeperCount': 0,
#       'tookLargeDamageSurvived': 0,
#       'turretPlatesTaken': 0,
#       'turretTakedowns': 3,
#       'turretsTakenWithRiftHerald': 0,
#       'twentyMinionsIn3SecondsCount': 0,
#       'unseenRecalls': 0,
#       'visionScoreAdvantageLaneOpponent': -1,
#       'visionScorePerMinute': 0,
#       'wardTakedowns': 0,
#       'wardTakedownsBefore20M': 0,
#       'wardsGuarded': 0},
#      'champExperience': 21672,
#      'champLevel': 18,
#      'championId': 1,
#      'championName': 'Annie',
#      'championTransform': 0,
#      'commandPings': 0,
#      'consumablesPurchased': 2,
#      'damageDealtToBuildings': 2599,
#      'damageDealtToObjectives': 2599,
#      'damageDealtToTurrets': 2599,
#      'damageSelfMitigated': 8034,
#      'dangerPings': 0,
#      'deaths': 10,
#      'detectorWardsPlaced': 0,
#      'doubleKills': 0,
#      'dragonKills': 0,
#      'eligibleForProgression': True,
#      'enemyMissingPings': 0,
#      'enemyVisionPings': 0,
#      'firstBloodAssist': False,
#      'firstBloodKill': False,
#      'firstTowerAssist': False,
#      'firstTowerKill': False,
#      'gameEndedInEarlySurrender': False,
#      'gameEndedInSurrender': False,
#      'getBackPings': 0,
#      'goldEarned': 12585,
#      'goldSpent': 11435,
#      'holdPings': 0,
#      'individualPosition': 'Invalid',
#      'inhibitorKills': 0,
#      'inhibitorTakedowns': 0,
#      'inhibitorsLost': 0,
#      'item0': 6653,
#      'item1': 4637,
#      'item2': 3020,
#      'item3': 3089,
#      'item4': 1052,
#      'item5': 0,
#      'item6': 2052,
#      'itemsPurchased': 14,
#      'killingSprees': 1,
#      'kills': 5,
#      'lane': 'MIDDLE',
#      'largestCriticalStrike': 0,
#      'largestKillingSpree': 2,
#      'largestMultiKill': 1,
#      'longestTimeSpentLiving': 124,
#      'magicDamageDealt': 30429,
#      'magicDamageDealtToChampions': 15784,
#      'magicDamageTaken': 15893,
#      'needVisionPings': 0,
#      'neutralMinionsKilled': 0,
#      'nexusKills': 0,
#      'nexusLost': 0,
#      'nexusTakedowns': 1,
#      'objectivesStolen': 0,
#      'objectivesStolenAssists': 0,
#      'onMyWayPings': 0,
#      'participantId': 9,
#      'pentaKills': 0,
#      'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#       'styles': [{'description': 'primaryStyle',
#         'selections': [{'perk': 8128, 'var1': 1433, 'var2': 23, 'var3': 0},
#          {'perk': 8126, 'var1': 797, 'var2': 0, 'var3': 0},
#          {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#          {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#         'style': 8100},
#        {'description': 'subStyle',
#         'selections': [{'perk': 8009, 'var1': 3153, 'var2': 0, 'var3': 0},
#          {'perk': 8014, 'var1': 763, 'var2': 0, 'var3': 0}],
#         'style': 8000}]},
#      'physicalDamageDealt': 2420,
#      'physicalDamageDealtToChampions': 783,
#      'physicalDamageTaken': 3656,
#      'profileIcon': 3172,
#      'pushPings': 0,
#      'puuid': 'u3t8EnIg-rw6EwPqawcyhtRXQ5GszEmCSH189VyZIIJITuMniZawO94B76mwIapopuycqWcNDeO7_g',
#      'quadraKills': 0,
#      'riotIdName': '',
#      'riotIdTagline': '',
#      'role': 'SUPPORT',
#      'sightWardsBoughtInGame': 0,
#      'spell1Casts': 24,
#      'spell2Casts': 34,
#      'spell3Casts': 46,
#      'spell4Casts': 22,
#      'summoner1Casts': 2,
#      'summoner1Id': 4,
#      'summoner2Casts': 4,
#      'summoner2Id': 7,
#      'summonerId': 'WQTIAB5_T3Mv9nVHFL3SpTYT1KmDIOKgeP0ZP78-sepk30c',
#      'summonerLevel': 206,
#      'summonerName': 'Rachel1e',
#      'teamEarlySurrendered': False,
#      'teamId': 200,
#      'teamPosition': '',
#      'timeCCingOthers': 14,
#      'timePlayed': 1241,
#      'totalDamageDealt': 35917,
#      'totalDamageDealtToChampions': 17224,
#      'totalDamageShieldedOnTeammates': 3762,
#      'totalDamageTaken': 20075,
#      'totalHeal': 1465,
#      'totalHealsOnTeammates': 447,
#      'totalMinionsKilled': 11,
#      'totalTimeCCDealt': 32,
#      'totalTimeSpentDead': 293,
#      'totalUnitsHealed': 4,
#      'tripleKills': 0,
#      'trueDamageDealt': 3066,
#      'trueDamageDealtToChampions': 656,
#      'trueDamageTaken': 524,
#      'turretKills': 0,
#      'turretTakedowns': 3,
#      'turretsLost': 2,
#      'unrealKills': 0,
#      'visionClearedPings': 0,
#      'visionScore': 0,
#      'visionWardsBoughtInGame': 0,
#      'wardsKilled': 0,
#      'wardsPlaced': 0,
#      'win': True},
#     {'allInPings': 0,
#      'assistMePings': 0,
#      'assists': 21,
#      'baitPings': 0,
#      'baronKills': 0,
#      'basicPings': 0,
#      'bountyLevel': 3,
#      'challenges': {'12AssistStreakCount': 0,
#       'abilityUses': 285,
#       'acesBefore15Minutes': 0,
#       'alliedJungleMonsterKills': 0,
#       'baronTakedowns': 0,
#       'blastConeOppositeOpponentCount': 0,
#       'bountyGold': 750,
#       'buffsStolen': 0,
#       'completeSupportQuestInTime': 0,
#       'controlWardsPlaced': 0,
#       'damagePerMinute': 2692.544102657678,
#       'damageTakenOnTeamPercentage': 0.18604421176066185,
#       'dancedWithRiftHerald': 0,
#       'deathsByEnemyChamps': 11,
#       'dodgeSkillShotsSmallWindow': 14,
#       'doubleAces': 0,
#       'dragonTakedowns': 0,
#       'earlyLaningPhaseGoldExpAdvantage': 0,
#       'effectiveHealAndShielding': 0,
#       'elderDragonKillsWithOpposingSoul': 0,
#       'elderDragonMultikills': 0,
#       'enemyChampionImmobilizations': 59,
#       'enemyJungleMonsterKills': 0,
#       'epicMonsterKillsNearEnemyJungler': 0,
#       'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#       'epicMonsterSteals': 0,
#       'epicMonsterStolenWithoutSmite': 0,
#       'flawlessAces': 1,
#       'fullTeamTakedown': 6,
#       'gameLength': 1241.154113019509,
#       'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#       'goldPerMinute': 848.8512613569688,
#       'hadOpenNexus': 0,
#       'highestChampionDamage': 1,
#       'immobilizeAndKillWithAlly': 15,
#       'initialBuffCount': 0,
#       'initialCrabCount': 0,
#       'jungleCsBefore10Minutes': 0,
#       'junglerTakedownsNearDamagedEpicMonster': 0,
#       'kTurretsDestroyedBeforePlatesFall': 1,
#       'kda': 3.8181818181818183,
#       'killAfterHiddenWithAlly': 5,
#       'killParticipation': 0.6268656716417911,
#       'killedChampTookFullTeamDamageSurvived': 0,
#       'killingSprees': 3,
#       'killsNearEnemyTurret': 8,
#       'killsOnOtherLanesEarlyJungleAsLaner': 0,
#       'killsOnRecentlyHealedByAramPack': 0,
#       'killsUnderOwnTurret': 2,
#       'killsWithHelpFromEpicMonster': 0,
#       'knockEnemyIntoTeamAndKill': 0,
#       'landSkillShotsEarlyGame': 11,
#       'laneMinionsFirst10Minutes': 43,
#       'laningPhaseGoldExpAdvantage': 0,
#       'legendaryCount': 0,
#       'lostAnInhibitor': 0,
#       'maxCsAdvantageOnLaneOpponent': 70,
#       'maxKillDeficit': 4,
#       'maxLevelLeadLaneOpponent': 2,
#       'moreEnemyJungleThanOpponent': 0,
#       'multiKillOneSpell': 0,
#       'multiTurretRiftHeraldCount': 0,
#       'multikills': 7,
#       'multikillsAfterAggressiveFlash': 1,
#       'mythicItemUsed': 6673,
#       'outerTurretExecutesBefore10Minutes': 0,
#       'outnumberedKills': 5,
#       'outnumberedNexusKill': 0,
#       'perfectDragonSoulsTaken': 0,
#       'perfectGame': 0,
#       'pickKillWithAlly': 27,
#       'poroExplosions': 0,
#       'quickCleanse': 0,
#       'quickFirstTurret': 0,
#       'quickSoloKills': 0,
#       'riftHeraldTakedowns': 0,
#       'saveAllyFromDeath': 0,
#       'scuttleCrabKills': 0,
#       'skillshotsDodged': 77,
#       'skillshotsHit': 26,
#       'snowballsHit': 14,
#       'soloBaronKills': 0,
#       'soloKills': 4,
#       'stealthWardsPlaced': 0,
#       'survivedSingleDigitHpCount': 0,
#       'survivedThreeImmobilizesInFight': 5,
#       'takedownOnFirstTurret': 0,
#       'takedowns': 42,
#       'takedownsAfterGainingLevelAdvantage': 2,
#       'takedownsBeforeJungleMinionSpawn': 0,
#       'takedownsFirstXMinutes': 31,
#       'takedownsInAlcove': 0,
#       'takedownsInEnemyFountain': 0,
#       'teamBaronKills': 0,
#       'teamDamagePercentage': 0.33372253475282665,
#       'teamElderDragonKills': 0,
#       'teamRiftHeraldKills': 0,
#       'threeWardsOneSweeperCount': 0,
#       'tookLargeDamageSurvived': 0,
#       'turretPlatesTaken': 0,
#       'turretTakedowns': 2,
#       'turretsTakenWithRiftHerald': 0,
#       'twentyMinionsIn3SecondsCount': 4,
#       'unseenRecalls': 0,
#       'visionScoreAdvantageLaneOpponent': -1,
#       'visionScorePerMinute': 0,
#       'wardTakedowns': 0,
#       'wardTakedownsBefore20M': 0,
#       'wardsGuarded': 0},
#      'champExperience': 21896,
#      'champLevel': 18,
#      'championId': 777,
#      'championName': 'Yone',
#      'championTransform': 0,
#      'commandPings': 0,
#      'consumablesPurchased': 0,
#      'damageDealtToBuildings': 2917,
#      'damageDealtToObjectives': 2917,
#      'damageDealtToTurrets': 2917,
#      'damageSelfMitigated': 37333,
#      'dangerPings': 0,
#      'deaths': 11,
#      'detectorWardsPlaced': 0,
#      'doubleKills': 5,
#      'dragonKills': 0,
#      'eligibleForProgression': True,
#      'enemyMissingPings': 0,
#      'enemyVisionPings': 0,
#      'firstBloodAssist': False,
#      'firstBloodKill': False,
#      'firstTowerAssist': False,
#      'firstTowerKill': False,
#      'gameEndedInEarlySurrender': False,
#      'gameEndedInSurrender': False,
#      'getBackPings': 0,
#      'goldEarned': 17559,
#      'goldSpent': 15365,
#      'holdPings': 0,
#      'individualPosition': 'Invalid',
#      'inhibitorKills': 0,
#      'inhibitorTakedowns': 0,
#      'inhibitorsLost': 0,
#      'item0': 3036,
#      'item1': 3006,
#      'item2': 6673,
#      'item3': 3031,
#      'item4': 3091,
#      'item5': 1057,
#      'item6': 2052,
#      'itemsPurchased': 19,
#      'killingSprees': 4,
#      'kills': 21,
#      'lane': 'MIDDLE',
#      'largestCriticalStrike': 918,
#      'largestKillingSpree': 7,
#      'largestMultiKill': 3,
#      'longestTimeSpentLiving': 151,
#      'magicDamageDealt': 19989,
#      'magicDamageDealtToChampions': 11100,
#      'magicDamageTaken': 18456,
#      'needVisionPings': 0,
#      'neutralMinionsKilled': 0,
#      'nexusKills': 0,
#      'nexusLost': 0,
#      'nexusTakedowns': 0,
#      'objectivesStolen': 0,
#      'objectivesStolenAssists': 0,
#      'onMyWayPings': 1,
#      'participantId': 10,
#      'pentaKills': 0,
#      'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#       'styles': [{'description': 'primaryStyle',
#         'selections': [{'perk': 8008, 'var1': 76, 'var2': 11, 'var3': 0},
#          {'perk': 9111, 'var1': 1953, 'var2': 420, 'var3': 0},
#          {'perk': 9105, 'var1': 4, 'var2': 0, 'var3': 0},
#          {'perk': 8017, 'var1': 1892, 'var2': 0, 'var3': 0}],
#         'style': 8000},
#        {'description': 'subStyle',
#         'selections': [{'perk': 8138, 'var1': 18, 'var2': 0, 'var3': 0},
#          {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#         'style': 8100}]},
#      'physicalDamageDealt': 95719,
#      'physicalDamageDealtToChampions': 36179,
#      'physicalDamageTaken': 12037,
#      'profileIcon': 1665,
#      'pushPings': 0,
#      'puuid': 'HZx6xJ9LEQe3fKia-USTJCQg4BZyLD59NtFd5jrifNYAgXK9izYELhKF109ZvAOx79r-xqrjrqA73Q',
#      'quadraKills': 0,
#      'riotIdName': '',
#      'riotIdTagline': '',
#      'role': 'CARRY',
#      'sightWardsBoughtInGame': 0,
#      'spell1Casts': 173,
#      'spell2Casts': 46,
#      'spell3Casts': 55,
#      'spell4Casts': 11,
#      'summoner1Casts': 3,
#      'summoner1Id': 4,
#      'summoner2Casts': 30,
#      'summoner2Id': 32,
#      'summonerId': 'BC841AxxJpSAdFCe8iQOjTQpbhlyxcMADIg1vXsrLHTItlo8W-dFo2urjQ',
#      'summonerLevel': 134,
#      'summonerName': 'Is massacre',
#      'teamEarlySurrendered': False,
#      'teamId': 200,
#      'teamPosition': '',
#      'timeCCingOthers': 36,
#      'timePlayed': 1241,
#      'totalDamageDealt': 124176,
#      'totalDamageDealtToChampions': 55697,
#      'totalDamageShieldedOnTeammates': 0,
#      'totalDamageTaken': 31125,
#      'totalHeal': 2671,
#      'totalHealsOnTeammates': 0,
#      'totalMinionsKilled': 94,
#      'totalTimeCCDealt': 78,
#      'totalTimeSpentDead': 346,
#      'totalUnitsHealed': 1,
#      'tripleKills': 2,
#      'trueDamageDealt': 8467,
#      'trueDamageDealtToChampions': 8417,
#      'trueDamageTaken': 631,
#      'turretKills': 0,
#      'turretTakedowns': 2,
#      'turretsLost': 2,
#      'unrealKills': 0,
#      'visionClearedPings': 0,
#      'visionScore': 0,
#      'visionWardsBoughtInGame': 0,
#      'wardsKilled': 0,
#      'wardsPlaced': 0,
#      'win': True}],
#    'platformId': 'EUW1',
#    'queueId': 450,
#    'teams': [{'bans': [],
#      'objectives': {'baron': {'first': False, 'kills': 0},
#       'champion': {'first': True, 'kills': 53},
#       'dragon': {'first': False, 'kills': 0},
#       'inhibitor': {'first': False, 'kills': 0},
#       'riftHerald': {'first': False, 'kills': 0},
#       'tower': {'first': True, 'kills': 2}},
#      'teamId': 100,
#      'win': False},
#     {'bans': [],
#      'objectives': {'baron': {'first': False, 'kills': 0},
#       'champion': {'first': False, 'kills': 67},
#       'dragon': {'first': False, 'kills': 0},
#       'inhibitor': {'first': True, 'kills': 1},
#       'riftHerald': {'first': False, 'kills': 0},
#       'tower': {'first': False, 'kills': 4}},
#      'teamId': 200,
#      'win': True}],
#    'tournamentCode': ''}}]

# %%
total_assists = 0

# %%
user_index = aggregated_result[0]['metadata']['participants'].index(AccountPuuid)

# %%
aggregated_result[i]['info']['participants'][user_index]['assists']
# Out:
# 2

# %%
for i in range(0,50):
    user_index = aggregated_result[i]['metadata']['participants'].index(AccountPuuid)
    extract_assists = aggregated_result[i]['info']['participants'][user_index]['assists']
    total_assists += extract_assists

# %%
total_assists
# Out:
# 420
